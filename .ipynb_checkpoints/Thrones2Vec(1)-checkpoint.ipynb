# %% [markdown]
# # Thrones2Vec

# %% [markdown]
# ## Imports

# %%
from __future__ import absolute_import, division, print_function

# %%
import gensim
import codecs
import glob
import logging
import multiprocessing
import os
import pprint
import re

# %%
import nltk
import gensim.models.word2vec as w2v
import sklearn.manifold
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# e:\programs\python36\lib\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['seed']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# **Set up logging**

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# **Download NLTK tokenizer models (only the first time)**

# %%
nltk.download("punkt")
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Tony\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Tony\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ## Prepare Corpus

# %% [markdown]
# **Load books from files**

# %%
book_filenames = sorted(glob.glob("data/*.txt"))

# %%
print("Found books:")
book_filenames
# Out:
# Found books:
# ['data\\got1.txt',
#  'data\\got2.txt',
#  'data\\got3.txt',
#  'data\\got4.txt',
#  'data\\got5.txt']

# %% [markdown]
# **Combine the books into one string**

# %%
corpus_raw = u""
for book_filename in book_filenames:
    print("Reading '{0}'...".format(book_filename))
    with codecs.open(book_filename, "r", "utf-8") as book_file:
        corpus_raw += book_file.read()
    print("Corpus is now {0} characters long".format(len(corpus_raw)))
    print()
# Out:
# Reading 'data\got1.txt'...
# Corpus is now 1770659 characters long
#
# Reading 'data\got2.txt'...
# Corpus is now 4071041 characters long
#
# Reading 'data\got3.txt'...
# Corpus is now 6391405 characters long
#
# Reading 'data\got4.txt'...
# Corpus is now 8107945 characters long
#
# Reading 'data\got5.txt'...
# Corpus is now 9719485 characters long

# %% [markdown]
# **Split the corpus into sentences**

# %%
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %%
raw_sentences = tokenizer.tokenize(corpus_raw)

# %%
#convert into a list of words
#rtemove unnnecessary,, split into words, no hyphens
#list of words
def sentence_to_wordlist(raw):
    clean = re.sub("[^a-zA-Z]"," ", raw)
    words = clean.split()
    return words

# %%
#sentence where each word is tokenized
sentences = []
for raw_sentence in raw_sentences:
    if len(raw_sentence) > 0:
        sentences.append(sentence_to_wordlist(raw_sentence))

# %%
print(raw_sentences[5])
print(sentence_to_wordlist(raw_sentences[5]))
# Out:
# Heraldic crest by Virginia Norey.
# ['Heraldic', 'crest', 'by', 'Virginia', 'Norey']

# %%
token_count = sum([len(sentence) for sentence in sentences])
print("The book corpus contains {0:,} tokens".format(token_count))
# Out:
# The book corpus contains 1,818,103 tokens

# %% [markdown]
# ## Train Word2Vec

# %%
#ONCE we have vectors
#step 3 - build model
#3 main tasks that vectors help with
#DISTANCE, SIMILARITY, RANKING

# Dimensionality of the resulting word vectors.
#more dimensions, more computationally expensive to train
#but also more accurate
#more dimensions = more generalized
num_features = 300
# Minimum word count threshold.
min_word_count = 3

# Number of threads to run in parallel.
#more workers, faster we train
num_workers = multiprocessing.cpu_count()

# Context window length.
context_size = 7

# Downsample setting for frequent words.
#0 - 1e-5 is good for this
downsampling = 1e-3

# Seed for the RNG, to make the results reproducible.
#random number generator
#deterministic, good for debugging
seed = 1

# %%
thrones2vec = w2v.Word2Vec(
    sg=1,
    seed=seed,
    workers=num_workers,
    size=num_features,
    min_count=min_word_count,
    window=context_size,
    sample=downsampling
)

# %%
thrones2vec.build_vocab(sentences)
# Out:
# 2019-01-31 18:16:34,708 : INFO : collecting all words and their counts
# 2019-01-31 18:16:34,709 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-01-31 18:16:34,751 : INFO : PROGRESS: at sentence #10000, processed 140984 words, keeping 10280 word types
# 2019-01-31 18:16:34,792 : INFO : PROGRESS: at sentence #20000, processed 279730 words, keeping 13558 word types
# 2019-01-31 18:16:34,831 : INFO : PROGRESS: at sentence #30000, processed 420336 words, keeping 16598 word types
# 2019-01-31 18:16:34,869 : INFO : PROGRESS: at sentence #40000, processed 556581 words, keeping 18324 word types
# 2019-01-31 18:16:34,909 : INFO : PROGRESS: at sentence #50000, processed 686247 words, keeping 19714 word types
# 2019-01-31 18:16:34,951 : INFO : PROGRESS: at sentence #60000, processed 828497 words, keeping 21672 word types
# 2019-01-31 18:16:34,995 : INFO : PROGRESS: at sentence #70000, processed 973830 words, keeping 23093 word types
# 2019-01-31 18:16:35,038 : INFO : PROGRESS: at sentence #80000, processed 1114967 words, keeping 24252 word types
# 2019-01-31 18:16:35,082 : INFO : PROGRESS: at sentence #90000, processed 1260481 words, keeping 26007 word types
# 2019-01-31 18:16:35,119 : INFO : PROGRESS: at sentence #100000, processed 1393203 words, keeping 26884 word types
# 2019-01-31 18:16:35,159 : INFO : PROGRESS: at sentence #110000, processed 1532150 words, keeping 27809 word types
# 2019-01-31 18:16:35,205 : INFO : PROGRESS: at sentence #120000, processed 1680961 words, keeping 28486 word types
# 2019-01-31 18:16:35,245 : INFO : collected 29026 word types from a corpus of 1818103 raw words and 128868 sentences
# 2019-01-31 18:16:35,246 : INFO : Loading a fresh vocabulary
# 2019-01-31 18:16:35,392 : INFO : effective_min_count=3 retains 17277 unique words (59% of original 29026, drops 11749)
# 2019-01-31 18:16:35,393 : INFO : effective_min_count=3 leaves 1802699 word corpus (99% of original 1818103, drops 15404)
# 2019-01-31 18:16:35,466 : INFO : deleting the raw counts dictionary of 29026 items
# 2019-01-31 18:16:35,468 : INFO : sample=0.001 downsamples 50 most-common words
# 2019-01-31 18:16:35,468 : INFO : downsampling leaves estimated 1404424 word corpus (77.9% of prior 1802699)
# 2019-01-31 18:16:35,542 : INFO : estimated required memory for 17277 words and 300 dimensions: 50103300 bytes
# 2019-01-31 18:16:35,543 : INFO : resetting layer weights

# %%
print("Word2Vec vocabulary length:", len(thrones2vec.wv.vocab))
# Out:
# Word2Vec vocabulary length: 17277

# %% [markdown]
# **Start training, this might take a minute or two...**

# %%
thrones2vec.train(total_examples=thrones2vec.corpus_count ,sentences = sentences, epochs = 10)
# Out:
# 2019-01-31 18:16:35,919 : INFO : training model with 8 workers on 17277 vocabulary and 300 features, using sg=1 hs=0 sample=0.001 negative=5 window=7
# 2019-01-31 18:16:36,932 : INFO : EPOCH 1 - PROGRESS: at 19.77% examples, 277304 words/s, in_qsize 15, out_qsize 0
# 2019-01-31 18:16:37,933 : INFO : EPOCH 1 - PROGRESS: at 43.96% examples, 300990 words/s, in_qsize 15, out_qsize 0
# 2019-01-31 18:16:38,934 : INFO : EPOCH 1 - PROGRESS: at 66.18% examples, 308663 words/s, in_qsize 15, out_qsize 0
# 2019-01-31 18:16:39,948 : INFO : EPOCH 1 - PROGRESS: at 89.47% examples, 309291 words/s, in_qsize 14, out_qsize 1
# 2019-01-31 18:16:40,274 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-01-31 18:16:40,283 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-01-31 18:16:40,319 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-01-31 18:16:40,325 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-01-31 18:16:40,341 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-01-31 18:16:40,350 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-01-31 18:16:40,367 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-01-31 18:16:40,409 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-01-31 18:16:40,411 : INFO : EPOCH - 1 : training on 1818103 raw words (1404582 effective words) took 4.5s, 313601 effective words/s
# 2019-01-31 18:16:41,432 : INFO : EPOCH 2 - PROGRESS: at 20.37% examples, 282581 words/s, in_qsize 16, out_qsize 0
# 2019-01-31 18:16:42,440 : INFO : EPOCH 2 - PROGRESS: at 45.49% examples, 309950 words/s, in_qsize 16, out_qsize 0
# 2019-01-31 18:16:43,459 : INFO : EPOCH 2 - PROGRESS: at 68.47% examples, 315401 words/s, in_qsize 16, out_qsize 0
# 2019-01-31 18:16:44,517 : INFO : EPOCH 2 - PROGRESS: at 92.42% examples, 314715 words/s, in_qsize 16, out_qsize 0
# 2019-01-31 18:16:44,715 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-01-31 18:16:44,719 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-01-31 18:16:44,751 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-01-31 18:16:44,754 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-01-31 18:16:44,760 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-01-31 18:16:44,777 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-01-31 18:16:44,779 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-01-31 18:16:44,826 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-01-31 18:16:44,827 : INFO : EPOCH - 2 : training on 1818103 raw words (1404599 effective words) took 4.4s, 318945 effective words/s
# 2019-01-31 18:16:45,840 : INFO : EPOCH 3 - PROGRESS: at 20.37% examples, 284418 words/s, in_qsize 15, out_qsize 0
# 2019-01-31 18:16:46,847 : INFO : EPOCH 3 - PROGRESS: at 44.99% examples, 307288 words/s, in_qsize 16, out_qsize 0
# 2019-01-31 18:16:47,851 : INFO : EPOCH 3 - PROGRESS: at 67.86% examples, 315188 words/s, in_qsize 14, out_qsize 1
# 2019-01-31 18:16:48,921 : INFO : EPOCH 3 - PROGRESS: at 92.42% examples, 315528 words/s, in_qsize 16, out_qsize 0
# 2019-01-31 18:16:49,111 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-01-31 18:16:49,128 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-01-31 18:16:49,146 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-01-31 18:16:49,156 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-01-31 18:16:49,170 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-01-31 18:16:49,181 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-01-31 18:16:49,199 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-01-31 18:16:49,221 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-01-31 18:16:49,223 : INFO : EPOCH - 3 : training on 1818103 raw words (1404126 effective words) took 4.4s, 320293 effective words/s
# 2019-01-31 18:16:50,254 : INFO : EPOCH 4 - PROGRESS: at 20.37% examples, 282441 words/s, in_qsize 16, out_qsize 0
# 2019-01-31 18:16:51,263 : INFO : EPOCH 4 - PROGRESS: at 45.49% examples, 309845 words/s, in_qsize 15, out_qsize 0
# 2019-01-31 18:16:52,274 : INFO : EPOCH 4 - PROGRESS: at 68.47% examples, 315967 words/s, in_qsize 15, out_qsize 0
# 2019-01-31 18:16:53,320 : INFO : EPOCH 4 - PROGRESS: at 92.42% examples, 316107 words/s, in_qsize 16, out_qsize 0
# 2019-01-31 18:16:53,530 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-01-31 18:16:53,535 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-01-31 18:16:53,539 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-01-31 18:16:53,551 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-01-31 18:16:53,569 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-01-31 18:16:53,579 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-01-31 18:16:53,590 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-01-31 18:16:53,603 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-01-31 18:16:53,604 : INFO : EPOCH - 4 : training on 1818103 raw words (1404724 effective words) took 4.4s, 322085 effective words/s
# 2019-01-31 18:16:54,661 : INFO : EPOCH 5 - PROGRESS: at 20.92% examples, 280465 words/s, in_qsize 15, out_qsize 0
# 2019-01-31 18:16:55,675 : INFO : EPOCH 5 - PROGRESS: at 46.57% examples, 311263 words/s, in_qsize 15, out_qsize 0
# 2019-01-31 18:16:56,686 : INFO : EPOCH 5 - PROGRESS: at 69.71% examples, 316979 words/s, in_qsize 16, out_qsize 0
# 2019-01-31 18:16:57,687 : INFO : EPOCH 5 - PROGRESS: at 92.42% examples, 316570 words/s, in_qsize 16, out_qsize 0
# 2019-01-31 18:16:57,890 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-01-31 18:16:57,899 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-01-31 18:16:57,903 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-01-31 18:16:57,912 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-01-31 18:16:57,925 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-01-31 18:16:57,928 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-01-31 18:16:57,950 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-01-31 18:16:57,964 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-01-31 18:16:57,966 : INFO : EPOCH - 5 : training on 1818103 raw words (1404349 effective words) took 4.3s, 322901 effective words/s
# 2019-01-31 18:16:58,984 : INFO : EPOCH 6 - PROGRESS: at 20.92% examples, 291150 words/s, in_qsize 15, out_qsize 0
# 2019-01-31 18:16:59,994 : INFO : EPOCH 6 - PROGRESS: at 45.49% examples, 310318 words/s, in_qsize 16, out_qsize 0
# 2019-01-31 18:17:01,011 : INFO : EPOCH 6 - PROGRESS: at 67.86% examples, 313245 words/s, in_qsize 15, out_qsize 0
# 2019-01-31 18:17:02,019 : INFO : EPOCH 6 - PROGRESS: at 91.92% examples, 317058 words/s, in_qsize 15, out_qsize 0
# 2019-01-31 18:17:02,288 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-01-31 18:17:02,304 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-01-31 18:17:02,306 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-01-31 18:17:02,310 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-01-31 18:17:02,313 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-01-31 18:17:02,339 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-01-31 18:17:02,366 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-01-31 18:17:02,386 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-01-31 18:17:02,387 : INFO : EPOCH - 6 : training on 1818103 raw words (1404658 effective words) took 4.4s, 318613 effective words/s
# 2019-01-31 18:17:03,404 : INFO : EPOCH 7 - PROGRESS: at 21.50% examples, 299580 words/s, in_qsize 14, out_qsize 1
# 2019-01-31 18:17:04,425 : INFO : EPOCH 7 - PROGRESS: at 45.49% examples, 308855 words/s, in_qsize 15, out_qsize 0
# 2019-01-31 18:17:05,429 : INFO : EPOCH 7 - PROGRESS: at 69.09% examples, 318684 words/s, in_qsize 15, out_qsize 0
# 2019-01-31 18:17:06,479 : INFO : EPOCH 7 - PROGRESS: at 92.42% examples, 315778 words/s, in_qsize 16, out_qsize 0
# 2019-01-31 18:17:06,679 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-01-31 18:17:06,691 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-01-31 18:17:06,714 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-01-31 18:17:06,720 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-01-31 18:17:06,732 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-01-31 18:17:06,741 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-01-31 18:17:06,756 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-01-31 18:17:06,778 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-01-31 18:17:06,780 : INFO : EPOCH - 7 : training on 1818103 raw words (1404370 effective words) took 4.4s, 320613 effective words/s
# 2019-01-31 18:17:07,794 : INFO : EPOCH 8 - PROGRESS: at 20.37% examples, 284414 words/s, in_qsize 16, out_qsize 0
# 2019-01-31 18:17:08,807 : INFO : EPOCH 8 - PROGRESS: at 45.49% examples, 310353 words/s, in_qsize 16, out_qsize 0
# 2019-01-31 18:17:09,820 : INFO : EPOCH 8 - PROGRESS: at 67.86% examples, 313672 words/s, in_qsize 16, out_qsize 0
# 2019-01-31 18:17:10,863 : INFO : EPOCH 8 - PROGRESS: at 92.42% examples, 316448 words/s, in_qsize 16, out_qsize 0
# 2019-01-31 18:17:11,058 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-01-31 18:17:11,064 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-01-31 18:17:11,074 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-01-31 18:17:11,118 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-01-31 18:17:11,128 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-01-31 18:17:11,135 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-01-31 18:17:11,143 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-01-31 18:17:11,171 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-01-31 18:17:11,172 : INFO : EPOCH - 8 : training on 1818103 raw words (1404326 effective words) took 4.4s, 320650 effective words/s
# 2019-01-31 18:17:12,206 : INFO : EPOCH 9 - PROGRESS: at 20.92% examples, 286528 words/s, in_qsize 16, out_qsize 0
# 2019-01-31 18:17:13,209 : INFO : EPOCH 9 - PROGRESS: at 45.52% examples, 308677 words/s, in_qsize 15, out_qsize 0
# 2019-01-31 18:17:14,212 : INFO : EPOCH 9 - PROGRESS: at 69.09% examples, 318739 words/s, in_qsize 15, out_qsize 0
# 2019-01-31 18:17:15,255 : INFO : EPOCH 9 - PROGRESS: at 92.42% examples, 316473 words/s, in_qsize 16, out_qsize 0
# 2019-01-31 18:17:15,457 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-01-31 18:17:15,468 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-01-31 18:17:15,472 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-01-31 18:17:15,474 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-01-31 18:17:15,476 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-01-31 18:17:15,488 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-01-31 18:17:15,508 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-01-31 18:17:15,531 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-01-31 18:17:15,533 : INFO : EPOCH - 9 : training on 1818103 raw words (1404424 effective words) took 4.3s, 322973 effective words/s
# 2019-01-31 18:17:16,562 : INFO : EPOCH 10 - PROGRESS: at 20.95% examples, 287751 words/s, in_qsize 15, out_qsize 0
# 2019-01-31 18:17:17,574 : INFO : EPOCH 10 - PROGRESS: at 44.46% examples, 300510 words/s, in_qsize 15, out_qsize 0
# 2019-01-31 18:17:18,610 : INFO : EPOCH 10 - PROGRESS: at 67.24% examples, 307227 words/s, in_qsize 15, out_qsize 0
# 2019-01-31 18:17:19,665 : INFO : EPOCH 10 - PROGRESS: at 92.42% examples, 312605 words/s, in_qsize 15, out_qsize 0
# 2019-01-31 18:17:19,861 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2019-01-31 18:17:19,873 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2019-01-31 18:17:19,884 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2019-01-31 18:17:19,894 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2019-01-31 18:17:19,900 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-01-31 18:17:19,935 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-01-31 18:17:19,939 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-01-31 18:17:19,949 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-01-31 18:17:19,950 : INFO : EPOCH - 10 : training on 1818103 raw words (1403689 effective words) took 4.4s, 318644 effective words/s
# 2019-01-31 18:17:19,951 : INFO : training on a 18181030 raw words (14043847 effective words) took 44.0s, 318947 effective words/s
# (14043847, 18181030)

# %% [markdown]
# **Save to file, can be useful later**

# %%
if not os.path.exists("trained"):
    os.makedirs("trained")

# %%
thrones2vec.wv.save_word2vec_format(os.path.join("trained", "thrones2vec.w2v"))
# Out:
# 2019-01-31 18:17:19,975 : INFO : storing 17277x300 projection weights into trained\thrones2vec.w2v

# %% [markdown]
# ## Explore the trained model.

# %%
thrones2vec = gensim.models.KeyedVectors.load_word2vec_format(os.path.join("trained", "thrones2vec.w2v"))
# Out:
# 2019-01-31 18:17:24,750 : INFO : loading projection weights from trained\thrones2vec.w2v
# 2019-01-31 18:17:30,779 : INFO : loaded (17277, 300) matrix from trained\thrones2vec.w2v

# %% [markdown]
# ### Compress the word vectors into 2D space and plot them

# %%
#Dimentionality reduction with t-sne
tsne = sklearn.manifold.TSNE(n_components=2, random_state=0)

# %%
all_word_vectors_matrix = thrones2vec.wv.syn0
# Out:
# e:\programs\python36\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """Entry point for launching an IPython kernel.
# e:\programs\python36\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.vectors instead).
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# **Train t-SNE, this could take a minute or two...**

# %%
all_word_vectors_matrix_2d = tsne.fit_transform(all_word_vectors_matrix)

# %% [markdown]
# **Plot the big picture**

# %%
points = pd.DataFrame(
    [
        (word, coords[0], coords[1])
        for word, coords in [
            (word, all_word_vectors_matrix_2d[thrones2vec.vocab[word].index])
            for word in thrones2vec.wv.vocab
        ]
    ],
    columns=["word", "x", "y"]
)
# Out:
# e:\programs\python36\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).

# %%
points.head(10)
# Out:
#   word          x          y
# 0  the   5.735368  12.097044
# 1  and   9.016944   5.065881
# 2   to -38.113724  -9.630238
# 3   of  -3.964402  -4.637154
# 4    a  -3.267974  -4.943729
# 5  his  33.441429 -25.785961
# 6  was -11.558046 -21.919821
# 7    I -41.047626 -16.454475
# 8   he -12.195640 -23.757492
# 9    s -29.785810  11.122601

# %%
sns.set_context("poster")

# %%
points.plot.scatter("x", "y", s=10, figsize=(20, 12))

# %% [markdown]
# **Zoom in to some interesting places**

# %%
def plot_region(x_bounds, y_bounds):
    slice = points.loc[
        (points['x'] >= x_bounds[0]) &
        (points['x'] <= x_bounds[1]) &
        (points['y'] >= y_bounds[0]) &
        (points['y'] <= y_bounds[1])
    ]
    
    ax = slice.plot.scatter("x", "y", s=35, figsize=(10, 10))
    for i, point in slice.iterrows():
        ax.text(point.x, point.y, point.word, fontsize=11)

# %% [markdown]
# **Function to print an area around a word**

# %%
def plot_region_around_word(word):
    offset = 1.1
    word_point = points[points['word'] == word]
    point = word_point.values
    #Finding the coordinates of the given word and seeing the plot around that value
    plot_region([point[0][1]- offset, point[0][1] + offset], [point[0][2]- offset, point[0][2]+offset])

# %% [markdown]
# **The model clustered food items together**

# %%
plot_region_around_word('bread')

# %% [markdown]
# ### Explore semantic similarities between book characters

# %% [markdown]
# **Words closest to the given word**

# %%
thrones2vec.most_similar("Stark")
# Out:
# 2019-01-31 18:35:52,750 : INFO : precomputing L2-norms of word weight vectors
# [('Eddard', 0.6536884903907776),
#  ('executed', 0.5517308712005615),
#  ('absently', 0.5102276802062988),
#  ('brotherly', 0.4766407907009125),
#  ('saddened', 0.4758799076080322),
#  ('Lyanna', 0.4734504222869873),
#  ('divulge', 0.4692629873752594),
#  ('Edrick', 0.4687919616699219),
#  ('Knelt', 0.46866321563720703),
#  ('Daryn', 0.46698540449142456)]

# %%
thrones2vec.most_similar("Aerys")
# Out:
# [('Jaehaerys', 0.6520094871520996),
#  ('II', 0.6389628052711487),
#  ('Conciliator', 0.6061580181121826),
#  ('Maekar', 0.5874843597412109),
#  ('Unlikely', 0.5867249965667725),
#  ('appointment', 0.5863174200057983),
#  ('Unworthy', 0.5843573212623596),
#  ('Daeron', 0.5730962753295898),
#  ('Mad', 0.5726089477539062),
#  ('Defiance', 0.5708019733428955)]

# %%
thrones2vec.most_similar("Tyrion")
# Out:
# [('dwarf', 0.5159129500389099),
#  ('Bronn', 0.45243000984191895),
#  ('Shae', 0.44958972930908203),
#  ('Griff', 0.43225517868995667),
#  ('Halfmaester', 0.4251852035522461),
#  ('irritation', 0.42478400468826294),
#  ('crookedly', 0.4245011806488037),
#  ('instantly', 0.42246213555336),
#  ('wearily', 0.41833919286727905),
#  ('exaggerated', 0.41293585300445557)]

# %% [markdown]
# **Linear relationships between word pairs**

# %%
def nearest_similarity_cosmul(start1, end1, end2):
    similarities = thrones2vec.most_similar_cosmul(
        positive=[end2, start1],
        negative=[end1]
    )
    start2 = similarities[0][0]
    print("{start1} is related to {end1}, as {start2} is related to {end2}".format(**locals()))
    return start2

# %%
nearest_similarity_cosmul("Stark", "Winterfell", "Riverrun")
nearest_similarity_cosmul("Jaime", "sword", "Tyrion")
# Out:
# Stark is related to Winterfell, as Tully is related to Riverrun
# Jaime is related to sword, as dwarf is related to Tyrion
# 'dwarf'
